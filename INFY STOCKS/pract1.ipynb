# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

# Load the data
data = pd.read_csv('infy_stock_data.csv')

# Preprocess the data (if necessary)
# For example, convert date column to datetime format and set it as index

# Visualize the time series
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Infosys Stock Price')
plt.legend()
plt.show()

# Check for stationarity (perform Dickey-Fuller test or visualize rolling statistics)

# Decompose the time series into trend, seasonal, and residual components (if necessary)

# Perform ARIMA modeling
# Determine the orders (p, d, q) using ACF and PACF plots
plot_acf(data['Close'])
plot_pacf(data['Close'])
plt.show()

# Fit the ARIMA model
p =0 # selected value for p
d =0 # selected value for d
q =0 # selected value for q
model = ARIMA(data['Close'], order=(p, d, q))
result = model.fit()

# Forecast future values
forecast = result.forecast(steps=10)  # specify the number of steps to forecast

# Plot the forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Close'], label='Actual')
plt.plot(np.arange(len(data), len(data) + len(forecast)), forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Infosys Stock Price Forecast')
plt.legend()
plt.show()

# Evaluate the model (calculate RMSE, MAE, etc.)

# Perform anomaly detection (e.g., using residuals or other techniques)
# Out:
# C:\Users\Ashutosh\AppData\Local\Temp\ipykernel_18312\785401544.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
