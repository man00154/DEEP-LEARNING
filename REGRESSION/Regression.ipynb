# %% [markdown]
# Create a regression dataset using scikit learn

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.datasets import make_regression
X, Y = make_regression(n_samples=3000, n_features=30, 
                       n_informative=28, noise=10, random_state=42)

# %%
X
# Out:
# array([[-0.71827942, -0.07007371, -2.8807235 , ...,  0.55875312,
#         -0.87841759, -0.31143446],
#        [-0.12946552,  0.4509102 , -0.22386779, ...,  0.47038416,
#         -2.21539143,  1.3816385 ],
#        [ 0.24136957,  1.13337657,  0.07615875, ..., -0.92070334,
#          0.20400935,  0.85537708],
#        ...,
#        [ 1.56947425, -0.98543931, -0.68558038, ...,  0.19199239,
#          0.47005926,  0.50240498],
#        [ 0.696168  ,  1.64337816, -0.08809124, ...,  0.75109945,
#         -1.97548777, -2.06508305],
#        [ 0.17293044,  1.05127132, -0.55991632, ..., -0.04062406,
#         -0.44272303,  1.14910819]])

# %%
X.shape
# Out:
# (3000, 30)

# %%
Y
# Out:
# array([ -45.03468463, -253.02652499,  496.76697472, ...,  207.02333227,
#        -828.35114667,  -98.9642237 ])

# %% [markdown]
# Converting X and Y to a dataframe

# %%
cols = [f'x{i+1}' for i in range(30)]
cols
# Out:
# ['x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x16',
#  'x17',
#  'x18',
#  'x19',
#  'x20',
#  'x21',
#  'x22',
#  'x23',
#  'x24',
#  'x25',
#  'x26',
#  'x27',
#  'x28',
#  'x29',
#  'x30']

# %%
import pandas as pd 
X = pd.DataFrame(X, columns=cols)
X.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -0.718279 -0.070074 -2.880723 -0.291797 -1.279408  0.360495 -2.030042
# 1 -0.129466  0.450910 -0.223868 -1.127200 -0.765647 -0.194988 -0.887412
# 2  0.241370  1.133377  0.076159 -0.597106 -0.569812 -1.097820 -0.405152
# 3 -0.066140  1.154356  0.065168  0.251785 -0.178338 -1.304646 -1.776299
# 4  0.630665 -1.333967 -0.606582  1.170996  1.342460 -1.284969  1.374057
#
#          x8        x9       x10  ...       x21       x22       x23       x24  \
# 0 -0.426785  0.442853  0.112514  ... -1.379176  0.545999 -1.238762  0.210254
# 1  0.706774 -0.341742  0.092110  ...  0.767348 -1.111131 -1.120872 -0.434288
# 2  0.360265  0.296881 -0.184067  ... -0.519368  1.398581  1.022523 -0.081239
# 3 -1.545955 -1.463394 -0.137389  ...  0.376657  1.021651  1.064456 -1.066433
# 4 -1.007511 -0.323503  0.265850  ... -0.500754  0.169756  0.967334  0.028729
#
#         x25       x26       x27       x28       x29       x30
# 0  2.233469  0.501408  0.311878  0.558753 -0.878418 -0.311434
# 1  0.826882 -0.244658  0.296457  0.470384 -2.215391  1.381639
# 2  0.339850  1.128266  1.101489 -0.920703  0.204009  0.855377
# 3 -1.620960  1.388090  1.764874 -0.946784 -0.095042  1.812141
# 4  0.757923  0.563454  0.625839  0.074512 -0.593699 -0.572639
#
# [5 rows x 30 columns]

# %%
Y = pd.DataFrame(Y, columns=['y'])
Y.head()
# Out:
#             y
# 0  -45.034685
# 1 -253.026525
# 2  496.766975
# 3   -4.601647
# 4  236.457790

# %% [markdown]
# Create a scikit learn pipeline for X

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('impute', SimpleImputer(strategy='mean')),
                           ('scaler', StandardScaler())]).set_output(transform='pandas')

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -0.688919 -0.057155 -2.863120 -0.305510 -1.275101  0.352911 -1.974449
# 1 -0.105807  0.470406 -0.205413 -1.147154 -0.763248 -0.201377 -0.849465
# 2  0.261436  1.161488  0.094710 -0.613100 -0.568141 -1.102267 -0.374652
# 3 -0.043094  1.182733  0.083716  0.242134 -0.178121 -1.308648 -1.724625
# 4  0.646962 -1.337003 -0.588250  1.168212  1.337030 -1.289013  1.377081
#
#          x8        x9       x10  ...       x21       x22       x23       x24  \
# 0 -0.412523  0.431024  0.109518  ... -1.402585  0.574088 -1.226719  0.191083
# 1  0.716442 -0.367298  0.090012  ...  0.772182 -1.104212 -1.110130 -0.448803
# 2  0.371337  0.282499 -0.174010  ... -0.531464  1.437562  1.009621 -0.098304
# 3 -1.527157 -1.508573 -0.129386  ...  0.376350  1.055817  1.051092 -1.076381
# 4 -0.990895 -0.348739  0.256105  ... -0.512606  0.193039  0.955041  0.010869
#
#         x25       x26       x27       x28       x29       x30
# 0  2.186029  0.475576  0.347794  0.578474 -0.918601 -0.325387
# 1  0.802196 -0.276927  0.332451  0.489438 -2.268167  1.395733
# 2  0.323041  1.107841  1.133389 -0.912149  0.174020  0.860754
# 3 -1.606051  1.369906  1.793399 -0.938426 -0.127848  1.833367
# 4  0.734352  0.538156  0.660157  0.090578 -0.631202 -0.590918
#
# [5 rows x 30 columns]

# %% [markdown]
# Apply train test split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=21)

# %%
xtrain.head()
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 1643  0.052039 -0.940475 -0.943021 -0.987331  1.090220  1.585467 -0.678379
# 137   1.253791 -0.710742 -1.791321  1.539163 -1.114221  1.012629  0.244713
# 1205  0.252961 -0.020081 -0.787437  1.481952 -0.891972  0.763080  0.103481
# 523   0.522782 -0.644630 -0.164250 -0.473433  1.297058  1.305110  0.098092
# 1493 -0.257471  0.131504 -0.411423  0.237039  1.631228  1.070852 -1.716534
#
#             x8        x9       x10  ...       x21       x22       x23  \
# 1643 -1.139013 -0.171146 -1.170170  ...  0.922744  0.526633  0.016138
# 137  -1.926104 -0.445870 -0.629977  ... -1.077994 -0.744548 -1.040224
# 1205 -0.422697 -0.032422 -0.897198  ... -0.213005 -0.275669  0.743194
# 523  -0.510435  1.836239  0.641412  ... -0.738259  1.205840  1.346459
# 1493 -1.038329  0.608915  0.980584  ... -1.106273 -0.672314 -0.409232
#
#            x24       x25       x26       x27       x28       x29       x30
# 1643  0.607965  0.333314 -1.520318  0.257526 -0.046280  0.278598  0.122691
# 137   0.435301 -0.454281  1.101016 -0.416873 -0.970135 -0.663722  0.115474
# 1205 -0.255197 -0.662567 -0.740384  1.096108  2.044021 -1.143672  0.657581
# 523   0.796726  1.464666  1.285444 -0.318203  1.055037  1.077651 -0.034905
# 1493 -0.574227 -0.049304 -1.098888  0.582422 -1.028832  1.017513  1.018863
#
# [5 rows x 30 columns]

# %%
ytrain.head()
# Out:
#                 y
# 1643   112.433915
# 137  -1083.527732
# 1205  -128.674183
# 523    761.187440
# 1493  -172.902429

# %%
xtest.head()
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 465  -0.169150  0.409952  1.307803  0.700982 -0.022220 -0.114715 -0.166075
# 904   0.637073 -1.927265  1.005873  0.295788 -1.197994  1.168578 -0.009949
# 2639  1.505908  0.342662  1.049776  0.563217  1.272666  0.319483 -0.145469
# 2125  0.700346  2.323657 -0.405742 -0.849900  0.199404 -0.194465 -0.126883
# 1962  0.222637  0.279963 -1.257113  0.583550 -0.564966 -1.512064  0.678992
#
#             x8        x9       x10  ...       x21       x22       x23  \
# 465   1.478153 -0.395357 -0.013553  ... -0.833916  1.384411  0.676108
# 904  -1.740025 -0.893787 -1.032446  ...  0.375229  0.321581  1.098016
# 2639  0.724367 -0.875059  1.157968  ... -0.361983 -0.488970  1.633057
# 2125 -0.110462  2.882282  0.295011  ... -0.451245  0.431099 -0.411627
# 1962 -2.255414  1.393263  0.905597  ... -0.992292 -0.802682  0.288486
#
#            x24       x25       x26       x27       x28       x29       x30
# 465  -0.296128 -0.309297  0.556642  0.432878 -0.163328 -1.799377  0.075014
# 904  -2.367612 -2.161798  0.942354  0.164110 -0.625070  1.951268 -0.588490
# 2639 -0.719981 -0.043802  0.555418  1.668127  1.919041 -0.105455  0.233323
# 2125  0.764152  1.172289 -0.002425 -0.254325 -2.008459  0.353949  0.749569
# 1962 -0.037195 -0.669431  0.305328 -1.311686 -1.082929  1.749682 -1.388976
#
# [5 rows x 30 columns]

# %%
ytest.head()
# Out:
#                y
# 465  -153.360317
# 904  -827.315745
# 2639  715.436126
# 2125  528.030227
# 1962  -44.600383

# %% [markdown]
# Build a Neural network

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
xtrain.shape
# Out:
# (2400, 30)

# %%
xtrain.shape[1]
# Out:
# 30

# %%
from keras.models import Sequential 
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From c:\Users\Ashutosh\Downloads\Deep Learnig 6_8 PM Thu Fri\repository\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Initialize the neural network
model = Sequential()

# Create hidden layer 1
model.add(Dense(units=64, activation='relu', input_shape=(xtrain.shape[1],)))
# Create 2nd hidden layer with 32
model.add(Dense(units=32, activation='relu'))
# Create a output layer
model.add(Dense(units=1, activation='linear'))
# Out:
# WARNING:tensorflow:From c:\Users\Ashutosh\Downloads\Deep Learnig 6_8 PM Thu Fri\repository\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Compiling the model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:From c:\Users\Ashutosh\Downloads\Deep Learnig 6_8 PM Thu Fri\repository\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Ashutosh\Downloads\Deep Learnig 6_8 PM Thu Fri\repository\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Ashutosh\Downloads\Deep Learnig 6_8 PM Thu Fri\repository\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 60/60 [==============================] - 1s 5ms/step - loss: 112400.1797 - mae: 265.4557 - val_loss: 115293.7812 - val_mae: 271.4271
# Epoch 2/100
# 60/60 [==============================] - 0s 2ms/step - loss: 109351.0391 - mae: 261.6582 - val_loss: 109449.1250 - val_mae: 264.3299
# Epoch 3/100
# 60/60 [==============================] - 0s 3ms/step - loss: 98034.1719 - mae: 246.8566 - val_loss: 91635.9609 - val_mae: 240.9113
# Epoch 4/100
# 60/60 [==============================] - 0s 2ms/step - loss: 72512.4141 - mae: 209.3008 - val_loss: 59219.2656 - val_mae: 190.3407
# Epoch 5/100
# 60/60 [==============================] - 0s 2ms/step - loss: 38184.4375 - mae: 145.4366 - val_loss: 25454.1133 - val_mae: 117.7814
# Epoch 6/100
# 60/60 [==============================] - 0s 2ms/step - loss: 13120.5166 - mae: 78.1691 - val_loss: 6967.7349 - val_mae: 56.6827
# Epoch 7/100
# 60/60 [==============================] - 0s 2ms/step - loss: 3647.9209 - mae: 40.9700 - val_loss: 2294.7229 - val_mae: 34.0609
# Epoch 8/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1635.4628 - mae: 30.2178 - val_loss: 1376.6920 - val_mae: 27.7511
# Epoch 9/100
# 60/60 [==============================] - 0s 2ms/step - loss: 1155.2930 - mae: 26.3803 - val_loss: 1012.5157 - val_mae: 24.1837
# Epoch 10/100
# 60/60 [==============================] - 0s 2ms/step - loss: 862.2641 - mae: 22.6916 - val_loss: 773.9655 - val_mae: 21.3867
# Epoch 11/100
# 60/60 [==============================] - 0s 2ms/step - loss: 717.4477 - mae: 20.9998 - val_loss: 684.7468 - val_mae: 20.5055
# Epoch 12/100
# 60/60 [==============================] - 0s 2ms/step - loss: 662.5579 - mae: 20.3600 - val_loss: 650.1801 - val_mae: 20.2397
# Epoch 13/100
# 60/60 [==============================] - 0s 2ms/step - loss: 631.4143 - mae: 19.8355 - val_loss: 622.4448 - val_mae: 19.9209
# Epoch 14/100
# 60/60 [==============================] - 0s 2ms/step - loss: 603.6466 - mae: 19.5384 - val_loss: 608.0370 - val_mae: 19.1187
# Epoch 15/100
# 60/60 [==============================] - 0s 2ms/step - loss: 581.3956 - mae: 19.0444 - val_loss: 580.5354 - val_mae: 19.0873
# Epoch 16/100
# 60/60 [==============================] - 0s 2ms/step - loss: 557.3956 - mae: 18.6705 - val_loss: 556.2226 - val_mae: 18.8284
# Epoch 17/100
# 60/60 [==============================] - 0s 2ms/step - loss: 535.6029 - mae: 18.3368 - val_loss: 538.7090 - val_mae: 18.7057
# Epoch 18/100
# 60/60 [==============================] - 0s 2ms/step - loss: 511.2596 - mae: 17.7742 - val_loss: 524.6387 - val_mae: 18.5024
# Epoch 19/100
# 60/60 [==============================] - 0s 2ms/step - loss: 493.0560 - mae: 17.6473 - val_loss: 502.2348 - val_mae: 17.9869
# Epoch 20/100
# 60/60 [==============================] - 0s 2ms/step - loss: 467.4630 - mae: 17.1039 - val_loss: 481.7940 - val_mae: 17.4703
# Epoch 21/100
# 60/60 [==============================] - 0s 2ms/step - loss: 444.5956 - mae: 16.6212 - val_loss: 465.0015 - val_mae: 17.2994
# Epoch 22/100
# 60/60 [==============================] - 0s 2ms/step - loss: 429.1668 - mae: 16.3906 - val_loss: 451.4056 - val_mae: 16.7278
# Epoch 23/100
# 60/60 [==============================] - 0s 2ms/step - loss: 408.3481 - mae: 15.8331 - val_loss: 427.1659 - val_mae: 16.4743
# Epoch 24/100
# 60/60 [==============================] - 0s 2ms/step - loss: 387.3261 - mae: 15.5135 - val_loss: 411.0961 - val_mae: 16.2851
# Epoch 25/100
# 60/60 [==============================] - 0s 2ms/step - loss: 371.0265 - mae: 15.1474 - val_loss: 396.7609 - val_mae: 16.0686
# Epoch 26/100
# 60/60 [==============================] - 0s 2ms/step - loss: 354.4839 - mae: 14.9347 - val_loss: 380.2461 - val_mae: 15.6973
# Epoch 27/100
# 60/60 [==============================] - 0s 2ms/step - loss: 335.6549 - mae: 14.3265 - val_loss: 365.2295 - val_mae: 15.2833
# Epoch 28/100
# 60/60 [==============================] - 0s 2ms/step - loss: 318.0385 - mae: 14.0220 - val_loss: 349.1972 - val_mae: 15.0231
# Epoch 29/100
# 60/60 [==============================] - 0s 3ms/step - loss: 302.6035 - mae: 13.6862 - val_loss: 336.3161 - val_mae: 14.6919
# Epoch 30/100
# 60/60 [==============================] - 0s 3ms/step - loss: 288.0622 - mae: 13.3221 - val_loss: 330.1494 - val_mae: 14.6800
# Epoch 31/100
# 60/60 [==============================] - 0s 2ms/step - loss: 275.5197 - mae: 12.9559 - val_loss: 319.8507 - val_mae: 14.5159
# Epoch 32/100
# 60/60 [==============================] - 0s 2ms/step - loss: 261.1742 - mae: 12.7415 - val_loss: 300.2405 - val_mae: 13.7670
# Epoch 33/100
# 60/60 [==============================] - 0s 2ms/step - loss: 247.3030 - mae: 12.3969 - val_loss: 290.5672 - val_mae: 13.5943
# Epoch 34/100
# 60/60 [==============================] - 0s 2ms/step - loss: 236.6033 - mae: 12.0220 - val_loss: 277.8231 - val_mae: 13.2805
# Epoch 35/100
# 60/60 [==============================] - 0s 2ms/step - loss: 224.8497 - mae: 11.7620 - val_loss: 269.8369 - val_mae: 13.0680
# Epoch 36/100
# 60/60 [==============================] - 0s 2ms/step - loss: 212.5638 - mae: 11.4395 - val_loss: 258.1012 - val_mae: 12.8350
# Epoch 37/100
# 60/60 [==============================] - 0s 2ms/step - loss: 202.7669 - mae: 11.1974 - val_loss: 248.9361 - val_mae: 12.6103
# Epoch 38/100
# 60/60 [==============================] - 0s 2ms/step - loss: 193.3425 - mae: 10.9227 - val_loss: 240.8215 - val_mae: 12.3991
# Epoch 39/100
# 60/60 [==============================] - 0s 2ms/step - loss: 185.1222 - mae: 10.7298 - val_loss: 232.6991 - val_mae: 12.1450
# Epoch 40/100
# 60/60 [==============================] - 0s 2ms/step - loss: 177.1143 - mae: 10.4398 - val_loss: 225.9154 - val_mae: 11.9448
# Epoch 41/100
# 60/60 [==============================] - 0s 2ms/step - loss: 167.3115 - mae: 10.2139 - val_loss: 220.2513 - val_mae: 11.7589
# Epoch 42/100
# 60/60 [==============================] - 0s 2ms/step - loss: 161.2570 - mae: 9.9247 - val_loss: 214.0803 - val_mae: 11.5806
# Epoch 43/100
# 60/60 [==============================] - 0s 2ms/step - loss: 154.9612 - mae: 9.7961 - val_loss: 204.9328 - val_mae: 11.3498
# Epoch 44/100
# 60/60 [==============================] - 0s 3ms/step - loss: 146.4984 - mae: 9.5241 - val_loss: 201.4465 - val_mae: 11.1777
# Epoch 45/100
# 60/60 [==============================] - 0s 2ms/step - loss: 143.0139 - mae: 9.3701 - val_loss: 199.4180 - val_mae: 11.1609
# Epoch 46/100
# 60/60 [==============================] - 0s 2ms/step - loss: 136.7302 - mae: 9.2111 - val_loss: 190.8127 - val_mae: 10.8764
# Epoch 47/100
# 60/60 [==============================] - 0s 2ms/step - loss: 129.6907 - mae: 8.9732 - val_loss: 188.7507 - val_mae: 10.8406
# Epoch 48/100
# 60/60 [==============================] - 0s 2ms/step - loss: 126.3890 - mae: 8.8361 - val_loss: 183.1539 - val_mae: 10.6655
# Epoch 49/100
# 60/60 [==============================] - 0s 2ms/step - loss: 123.4091 - mae: 8.7782 - val_loss: 180.1668 - val_mae: 10.5680
# Epoch 50/100
# 60/60 [==============================] - 0s 2ms/step - loss: 118.8170 - mae: 8.5923 - val_loss: 175.8058 - val_mae: 10.4514
# Epoch 51/100
# 60/60 [==============================] - 0s 2ms/step - loss: 113.7655 - mae: 8.3986 - val_loss: 172.4840 - val_mae: 10.3324
# Epoch 52/100
# 60/60 [==============================] - 0s 2ms/step - loss: 111.2995 - mae: 8.3242 - val_loss: 172.8071 - val_mae: 10.3474
# Epoch 53/100
# 60/60 [==============================] - 0s 2ms/step - loss: 107.5654 - mae: 8.1735 - val_loss: 167.1794 - val_mae: 10.1483
# Epoch 54/100
# 60/60 [==============================] - 0s 2ms/step - loss: 105.3303 - mae: 8.0362 - val_loss: 164.9300 - val_mae: 10.0596
# Epoch 55/100
# 60/60 [==============================] - 0s 2ms/step - loss: 101.9171 - mae: 7.9857 - val_loss: 163.6641 - val_mae: 10.0491
# Epoch 56/100
# 60/60 [==============================] - 0s 2ms/step - loss: 100.0069 - mae: 7.8384 - val_loss: 162.7525 - val_mae: 10.0636
# Epoch 57/100
# 60/60 [==============================] - 0s 2ms/step - loss: 97.1310 - mae: 7.7551 - val_loss: 160.6257 - val_mae: 9.9418
# Epoch 58/100
# 60/60 [==============================] - 0s 2ms/step - loss: 96.0235 - mae: 7.7325 - val_loss: 159.8942 - val_mae: 9.9607
# Epoch 59/100
# 60/60 [==============================] - 0s 2ms/step - loss: 93.1617 - mae: 7.6114 - val_loss: 159.4041 - val_mae: 9.8990
# Epoch 60/100
# 60/60 [==============================] - 0s 2ms/step - loss: 92.3267 - mae: 7.5634 - val_loss: 160.0445 - val_mae: 9.9204
# Epoch 61/100
# 60/60 [==============================] - 0s 2ms/step - loss: 90.2609 - mae: 7.4947 - val_loss: 157.0726 - val_mae: 9.7967
# Epoch 62/100
# 60/60 [==============================] - 0s 2ms/step - loss: 89.6068 - mae: 7.4577 - val_loss: 159.8018 - val_mae: 9.9271
# Epoch 63/100
# 60/60 [==============================] - 0s 2ms/step - loss: 88.9843 - mae: 7.4221 - val_loss: 155.2236 - val_mae: 9.7339
# Epoch 64/100
# 60/60 [==============================] - 0s 2ms/step - loss: 86.7413 - mae: 7.3127 - val_loss: 155.2896 - val_mae: 9.7678
# Epoch 65/100
# 60/60 [==============================] - 0s 2ms/step - loss: 84.9076 - mae: 7.2566 - val_loss: 155.7199 - val_mae: 9.8332
# Epoch 66/100
# 60/60 [==============================] - 0s 2ms/step - loss: 84.0737 - mae: 7.1910 - val_loss: 154.3298 - val_mae: 9.7472
# Epoch 67/100
# 60/60 [==============================] - 0s 2ms/step - loss: 82.9864 - mae: 7.1519 - val_loss: 156.4423 - val_mae: 9.8408
# Epoch 68/100
# 60/60 [==============================] - 0s 2ms/step - loss: 81.1995 - mae: 7.0427 - val_loss: 153.7544 - val_mae: 9.6991
# Epoch 69/100
# 60/60 [==============================] - 0s 2ms/step - loss: 79.8487 - mae: 7.0048 - val_loss: 152.2700 - val_mae: 9.7050
# Epoch 70/100
# 60/60 [==============================] - 0s 2ms/step - loss: 78.8826 - mae: 6.9716 - val_loss: 155.7484 - val_mae: 9.8318
# Epoch 71/100
# 60/60 [==============================] - 0s 2ms/step - loss: 78.6719 - mae: 6.9465 - val_loss: 153.6089 - val_mae: 9.6779
# Epoch 72/100
# 60/60 [==============================] - 0s 2ms/step - loss: 77.3155 - mae: 6.8953 - val_loss: 151.7302 - val_mae: 9.7174
# Epoch 73/100
# 60/60 [==============================] - 0s 2ms/step - loss: 77.1968 - mae: 6.8714 - val_loss: 154.1611 - val_mae: 9.7473
# Epoch 74/100
# 60/60 [==============================] - 0s 2ms/step - loss: 76.1782 - mae: 6.8456 - val_loss: 153.5376 - val_mae: 9.7261
# Epoch 75/100
# 60/60 [==============================] - 0s 2ms/step - loss: 75.7682 - mae: 6.8006 - val_loss: 152.6842 - val_mae: 9.7882
# Epoch 76/100
# 60/60 [==============================] - 0s 2ms/step - loss: 74.5753 - mae: 6.7614 - val_loss: 150.9117 - val_mae: 9.6858
# Epoch 77/100
# 60/60 [==============================] - 0s 2ms/step - loss: 73.5400 - mae: 6.7002 - val_loss: 152.7327 - val_mae: 9.7260
# Epoch 78/100
# 60/60 [==============================] - 0s 2ms/step - loss: 72.8984 - mae: 6.7077 - val_loss: 153.6460 - val_mae: 9.6931
# Epoch 79/100
# 60/60 [==============================] - 0s 2ms/step - loss: 71.2147 - mae: 6.5793 - val_loss: 152.4267 - val_mae: 9.7284
# Epoch 80/100
# 60/60 [==============================] - 0s 2ms/step - loss: 72.0153 - mae: 6.5962 - val_loss: 154.6805 - val_mae: 9.7759
# Epoch 81/100
# 60/60 [==============================] - 0s 2ms/step - loss: 70.4927 - mae: 6.5290 - val_loss: 154.8652 - val_mae: 9.7207
# Epoch 82/100
# 60/60 [==============================] - 0s 2ms/step - loss: 70.1729 - mae: 6.5659 - val_loss: 157.0233 - val_mae: 9.9886
# Epoch 83/100
# 60/60 [==============================] - 0s 2ms/step - loss: 69.4837 - mae: 6.4738 - val_loss: 154.5593 - val_mae: 9.7674
# Epoch 84/100
# 60/60 [==============================] - 0s 2ms/step - loss: 68.9193 - mae: 6.4254 - val_loss: 154.6438 - val_mae: 9.8084
# Epoch 85/100
# 60/60 [==============================] - 0s 2ms/step - loss: 69.8408 - mae: 6.5071 - val_loss: 152.6964 - val_mae: 9.7158
# Epoch 86/100
# 60/60 [==============================] - 0s 2ms/step - loss: 68.8808 - mae: 6.4776 - val_loss: 154.2726 - val_mae: 9.7640
# Epoch 87/100
# 60/60 [==============================] - 0s 3ms/step - loss: 66.7049 - mae: 6.3117 - val_loss: 153.5408 - val_mae: 9.6877
# Epoch 88/100
# 60/60 [==============================] - 0s 2ms/step - loss: 67.1609 - mae: 6.3279 - val_loss: 153.0369 - val_mae: 9.7202
# Epoch 89/100
# 60/60 [==============================] - 0s 2ms/step - loss: 66.8809 - mae: 6.3092 - val_loss: 155.2120 - val_mae: 9.8534
# Epoch 90/100
# 60/60 [==============================] - 0s 2ms/step - loss: 66.9197 - mae: 6.3553 - val_loss: 162.5288 - val_mae: 10.1041
# Epoch 91/100
# 60/60 [==============================] - 0s 2ms/step - loss: 66.5204 - mae: 6.3337 - val_loss: 153.7077 - val_mae: 9.7035
# Epoch 92/100
# 60/60 [==============================] - 0s 2ms/step - loss: 65.1411 - mae: 6.2522 - val_loss: 153.5616 - val_mae: 9.7045
# Epoch 93/100
# 60/60 [==============================] - 0s 2ms/step - loss: 65.0099 - mae: 6.2501 - val_loss: 156.5808 - val_mae: 9.8484
# Epoch 94/100
# 60/60 [==============================] - 0s 2ms/step - loss: 64.7338 - mae: 6.2163 - val_loss: 156.1493 - val_mae: 9.8788
# Epoch 95/100
# 60/60 [==============================] - 0s 2ms/step - loss: 66.3345 - mae: 6.3498 - val_loss: 158.4422 - val_mae: 9.9689
# Epoch 96/100
# 60/60 [==============================] - 0s 2ms/step - loss: 62.6110 - mae: 6.1265 - val_loss: 157.7392 - val_mae: 9.9227
# Epoch 97/100
# 60/60 [==============================] - 0s 2ms/step - loss: 63.3097 - mae: 6.1979 - val_loss: 153.5684 - val_mae: 9.7836
# Epoch 98/100
# 60/60 [==============================] - 0s 2ms/step - loss: 63.1857 - mae: 6.1795 - val_loss: 158.2970 - val_mae: 9.9253
# Epoch 99/100
# 60/60 [==============================] - 0s 2ms/step - loss: 62.9842 - mae: 6.1073 - val_loss: 159.2513 - val_mae: 10.0271
# Epoch 100/100
# 60/60 [==============================] - 0s 2ms/step - loss: 60.7403 - mae: 5.9798 - val_loss: 154.0481 - val_mae: 9.7943

# %% [markdown]
# Plot the learning curve

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,5))
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %% [markdown]
# Evaluate the model

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 75/75 [==============================] - 0s 2ms/step - loss: 76.1599 - mae: 6.5997
# [76.15989685058594, 6.599682331085205]

# %%
model.evaluate(xtest, ytest)
# Out:
# 19/19 [==============================] - 0s 931us/step - loss: 169.8229 - mae: 10.3300
# [169.82293701171875, 10.32996940612793]

# %% [markdown]
# Predicting values for train and test

# %%
ypred_tr = model.predict(xtrain)
ypred_ts = model.predict(xtest)
# Out:
# 75/75 [==============================] - 0s 1ms/step
# 19/19 [==============================] - 0s 812us/step

# %%
ypred_tr[0:5]
# Out:
# array([[  116.41094],
#        [-1060.2863 ],
#        [ -124.14147],
#        [  759.55707],
#        [ -185.56323]], dtype=float32)

# %%
ytrain.head()
# Out:
#                 y
# 1643   112.433915
# 137  -1083.527732
# 1205  -128.674183
# 523    761.187440
# 1493  -172.902429

# %%
ypred_ts[0:5]
# Out:
# array([[-158.10014 ],
#        [-829.76196 ],
#        [ 721.86066 ],
#        [ 517.6802  ],
#        [ -40.289238]], dtype=float32)

# %%
ytest.head()
# Out:
#                y
# 465  -153.360317
# 904  -827.315745
# 2639  715.436126
# 2125  528.030227
# 1962  -44.600383

# %% [markdown]
# Calculating R2 score in train and test

# %%
from sklearn.metrics import r2_score

# %%
tr_r2 = r2_score(ytrain, ypred_tr)
tr_r2
# Out:
# 0.999328996163072

# %%
ts_r2 = r2_score(ytest, ypred_ts)
ts_r2
# Out:
# 0.9985721463493383

# %% [markdown]
# Saving the neural network model for given dataset

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4097 (16.00 KB)
# Trainable params: 4097 (16.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save('Regression.keras')

# %% [markdown]
# Loading the model

# %%
from keras.models import load_model
nn = load_model('Regression.keras')
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4097 (16.00 KB)
# Trainable params: 4097 (16.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
